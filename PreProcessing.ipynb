# %% [markdown]
# # importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %% [markdown]
# # importing and exploring the Data

# %%
dataset = pd.read_excel('data.xlsx')

# %%
data = dataset.copy()

# %%
data.head()
# Out:
#    Column1          Start Time  Playtime  Effective Playtime  Interruptions  \
# 0        0 2022-07-12 00:00:14        11                  10              0
# 1        1 2022-07-12 00:00:38        73                  72              0
# 2        2 2022-07-12 00:02:02        21                  20              0
# 3        3 2022-07-12 00:02:24         1                   0              0
# 4        4 2022-07-12 00:02:25         1                   0              0
#
#    Join Time  Buffer Ratio CDN Node Host Connection Type      Device  ...  \
# 0      0.879           0.0           NaN    Ethernet-100  Android TV  ...
# 1      1.170           0.0           NaN          WiFi-5  Android TV  ...
# 2      1.133           0.0           NaN          WiFi-5  Android TV  ...
# 3      0.000           0.0           NaN          WiFi-5  Android TV  ...
# 4      0.000           0.0           NaN          WiFi-5  Android TV  ...
#
#   End of Playback Status User_ID_N Title_N Program_N Device_Vendor_N  \
# 0                On Stop       564     784         0              16
# 1                On Stop       480       1         0              13
# 2                On Stop       346     786         0              13
# 3                On Stop       346     997         0              13
# 4                On Stop       346     997         0              13
#
#   Device_Model_N Content_TV_Show_N  Country_N  City_N  Region_N
# 0             64              2672          3     263         0
# 1             63              2672          3      76         0
# 2             63              2672          3      76         0
# 3             63              2672          3      76         0
# 4             63              2672          3      76         0
#
# [5 rows x 33 columns]

# %%
data.shape
# Out:
# (102256, 33)

# %%
plt.figure(figsize=(10, 6))
plt.plot(data['Start Time'], data['Join Time'])
plt.title('Time Series Plot')
plt.xlabel('Start Time')
plt.ylabel('Value')
plt.show()

# %%
print(data.columns.values)
# Out:
# ['Column1' 'Start Time' 'Playtime' 'Effective Playtime' 'Interruptions'
#  'Join Time' 'Buffer Ratio' 'CDN Node Host' 'Connection Type' 'Device'
#  'Device Type' 'Browser' 'Browser Version' 'OS' 'OS Version' 'Device ID'
#  'Happiness Value' 'Happiness Score' 'Playback Stalls'
#  'Startup Error (Count)' 'Latency' 'End Time' 'Crash Status'
#  'End of Playback Status' 'User_ID_N' 'Title_N' 'Program_N'
#  'Device_Vendor_N' 'Device_Model_N' 'Content_TV_Show_N' 'Country_N'
#  'City_N' 'Region_N']

# %%
data.dtypes
# Out:
# Column1                            int64
# Start Time                datetime64[ns]
# Playtime                           int64
# Effective Playtime                 int64
# Interruptions                      int64
# Join Time                        float64
# Buffer Ratio                     float64
# CDN Node Host                     object
# Connection Type                   object
# Device                            object
# Device Type                       object
# Browser                           object
# Browser Version                   object
# OS                                object
# OS Version                        object
# Device ID                         object
# Happiness Value                   object
# Happiness Score                  float64
# Playback Stalls                  float64
# Startup Error (Count)              int64
# Latency                            int64
# End Time                  datetime64[ns]
# Crash Status                      object
# End of Playback Status            object
# User_ID_N                          int64
# Title_N                            int64
# Program_N                          int64
# Device_Vendor_N                    int64
# Device_Model_N                     int64
# Content_TV_Show_N                  int64
# Country_N                          int64
# City_N                             int64
# Region_N                           int64
# dtype: object

# %%
df=data.drop(columns=['Column1','Content_TV_Show_N','Device ID','Happiness Score','User_ID_N'])

# %%
df['Start Time'] = pd.to_datetime(df['Start Time'])
data_collection_duration = df['Start Time'].max() - df['Start Time'].min()
print(data_collection_duration)
# Out:
# 13 days 23:59:42

# %%
print(df.describe())
# Out:
#            Column1       Playtime  Effective Playtime  Interruptions  \
# count  102256.0000  102256.000000       102256.000000  102256.000000
# mean    51127.5000     328.965479          288.338454       0.099544
# std     29518.9089    1799.357645         1697.491699      12.007473
# min         0.0000       0.000000            0.000000       0.000000
# 25%     25563.7500       4.000000            1.000000       0.000000
# 50%     51127.5000      22.000000           17.000000       0.000000
# 75%     76691.2500      90.000000           75.000000       0.000000
# max    102255.0000   86404.000000        86402.000000    3786.000000
#
#            Join Time   Buffer Ratio  Happiness Score  Playback Stalls  \
# count  102256.000000  102256.000000    102256.000000    102256.000000
# mean        1.158462       0.261755         5.166843         0.003805
# std         2.843884       3.568773         4.381398         0.202198
# min         0.000000       0.000000        -1.000000         0.000000
# 25%         0.583000       0.000000         0.000000         0.000000
# 50%         0.790000       0.000000         6.646500         0.000000
# 75%         1.302000       0.000000         9.607000         0.000000
# max       120.000000     100.000000        10.000000        44.408000
#
#        Startup Error (Count)        Latency      User_ID_N        Title_N  \
# count          102256.000000  102256.000000  102256.000000  102256.000000
# mean                0.013564   13360.818788     392.976686     809.658494
# std                 0.115673   23550.856009     161.309073     527.743379
# min                 0.000000       0.000000       0.000000       0.000000
# 25%                 0.000000       0.000000     295.000000     261.000000
# 50%                 0.000000   17862.000000     383.000000     997.000000
# 75%                 0.000000   19235.000000     487.000000    1170.250000
# max                 1.000000  359477.000000     699.000000    1638.000000
#
#        Program_N  Device_Vendor_N  Device_Model_N  Content_TV_Show_N  \
# count   102256.0    102256.000000   102256.000000      102256.000000
# mean         0.0        13.127699       69.461704        2421.410568
# std          0.0         4.624751       33.347175         631.704165
# min          0.0         0.000000        0.000000           0.000000
# 25%          0.0        13.000000       63.000000        2672.000000
# 50%          0.0        15.000000       64.000000        2672.000000
# 75%          0.0        16.000000       64.000000        2672.000000
# max          0.0        24.000000      163.000000        2746.000000
#
#            Country_N         City_N       Region_N
# count  102256.000000  102256.000000  102256.000000
# mean        3.933021     150.772669       0.027676
# std         2.546806     107.740597       0.164043
# min         0.000000       0.000000       0.000000
# 25%         3.000000      76.000000       0.000000
# 50%         3.000000      76.000000       0.000000
# 75%         3.000000     240.000000       0.000000
# max        14.000000     405.000000       1.000000

# %%
plt.figure(figsize=(14,7))
cor = df.corr()
sns.heatmap(cor, annot=True, cmap='coolwarm')
plt.show()

# %%
df=df.drop(columns=['Program_N'])

# %%
df.isnull().sum(axis = 0)
# Out:
# Start Time                     0
# Playtime                       0
# Effective Playtime             0
# Interruptions                  0
# Join Time                      0
# Buffer Ratio                   0
# CDN Node Host              65277
# Connection Type                0
# Device                         0
# Device Type                    0
# Browser                        0
# Browser Version              845
# OS                             0
# OS Version                     0
# Happiness Value                1
# Playback Stalls                0
# Startup Error (Count)          0
# Latency                        0
# End Time                       0
# Crash Status              100411
# End of Playback Status         1
# Title_N                        0
# Device_Vendor_N                0
# Device_Model_N                 0
# Country_N                      0
# City_N                         0
# Region_N                       0
# dtype: int64

# %%
df.drop(columns=['CDN Node Host'], inplace=True)
df.drop(columns=['Crash Status'], inplace=True)

browser_version_mode = df['Browser Version'].mode().iloc[0]
df['Browser Version'].fillna(browser_version_mode, inplace=True)
df.dropna(subset=['Happiness Value', 'End of Playback Status',], inplace=True)
print(df.isnull().sum(axis=0))
# Out:
# Start Time                0
# Playtime                  0
# Effective Playtime        0
# Interruptions             0
# Join Time                 0
# Buffer Ratio              0
# Connection Type           0
# Device                    0
# Device Type               0
# Browser                   0
# Browser Version           0
# OS                        0
# OS Version                0
# Happiness Value           0
# Playback Stalls           0
# Startup Error (Count)     0
# Latency                   0
# End Time                  0
# End of Playback Status    0
# Title_N                   0
# Device_Vendor_N           0
# Device_Model_N            0
# Country_N                 0
# City_N                    0
# Region_N                  0
# dtype: int64

# %% [markdown]
# # preprocessing the data

# %%
df1 = df.copy()

# %%
numerical_v = df1._get_numeric_data()
numerical_c = numerical_v.columns
scaler = MinMaxScaler()
df1[numerical_c] = scaler.fit_transform(df1[numerical_c])
numerical_v = df1._get_numeric_data()

# %%
numerical_v
# Out:
#         Playtime  Effective Playtime  Interruptions  Join Time  Buffer Ratio  \
# 0       0.000127            0.000116       0.000000   0.007325       0.00000
# 1       0.000845            0.000833       0.000000   0.009750       0.00000
# 2       0.000243            0.000231       0.000000   0.009442       0.00000
# 3       0.000012            0.000000       0.000000   0.000000       0.00000
# 4       0.000012            0.000000       0.000000   0.000000       0.00000
# ...          ...                 ...            ...        ...           ...
# 102251  0.176867            0.000000       0.000000   0.000000       0.00000
# 102252  0.191912            0.191905       0.000000   0.008250       0.00000
# 102253  0.244966            0.000000       0.000000   0.000000       0.00000
# 102254  0.753692            0.753628       0.000528   0.050858       0.00001
# 102255  0.877702            0.876334       0.000000   1.000000       0.00000
#
#         Playback Stalls  Startup Error (Count)   Latency   Title_N  \
# 0                   0.0                    0.0  0.054257  0.478632
# 1                   0.0                    0.0  0.052946  0.000611
# 2                   0.0                    0.0  0.053052  0.479853
# 3                   0.0                    0.0  0.000000  0.608669
# 4                   0.0                    0.0  0.000000  0.608669
# ...                 ...                    ...       ...       ...
# 102251              0.0                    0.0  0.000000  0.918193
# 102252              0.0                    0.0  0.050604  0.619048
# 102253              0.0                    0.0  0.000000  0.656899
# 102254              0.0                    0.0  0.076639  0.877289
# 102255              0.0                    1.0  0.100938  0.550672
#
#         Device_Vendor_N  Device_Model_N  Country_N    City_N  Region_N
# 0              0.666667        0.392638   0.214286  0.649383       0.0
# 1              0.541667        0.386503   0.214286  0.187654       0.0
# 2              0.541667        0.386503   0.214286  0.187654       0.0
# 3              0.541667        0.386503   0.214286  0.187654       0.0
# 4              0.541667        0.386503   0.214286  0.187654       0.0
# ...                 ...             ...        ...       ...       ...
# 102251         0.083333        0.938650   0.214286  0.906173       0.0
# 102252         0.541667        0.386503   0.214286  0.096296       0.0
# 102253         0.666667        0.251534   0.214286  0.138272       0.0
# 102254         0.333333        0.969325   0.214286  0.138272       0.0
# 102255         0.541667        0.092025   0.214286  0.649383       0.0
#
# [102255 rows x 14 columns]

# %%
df2 = df1.copy()

# %%
df2['Happiness Value'].head(10)
# Out:
# 0     Smile (7-8.5)
# 1    Happy (8.5-10)
# 2     Neutral (5-7)
# 3       Angry (0-3)
# 4       Angry (0-3)
# 5       Angry (0-3)
# 6    Happy (8.5-10)
# 7       Angry (0-3)
# 8     Smile (7-8.5)
# 9       Angry (0-3)
# Name: Happiness Value, dtype: object

# %%
order = ['Angry (0-3)', 'Sad (3-5)', 'Neutral (5-7)', 'Smile (7-8.5)', 'Happy (8.5-10)']
print(f"\033[31m{df2['Happiness Value'].unique()}\033[31m")
encoder = OrdinalEncoder(categories=[order])
encoder.fit(df2[['Happiness Value']])
df2['Happiness Value'] = encoder.transform(df2[['Happiness Value']])
print(f"\033[32m{df2['Happiness Value'].unique()}\033[32m")
# Out:
# ['Smile (7-8.5)' 'Happy (8.5-10)' 'Neutral (5-7)' 'Angry (0-3)'
#  'Sad (3-5)']
# [3. 4. 2. 0. 1.]

# %%
df2['Happiness Value'].head(10)
# Out:
# 0    3.0
# 1    4.0
# 2    2.0
# 3    0.0
# 4    0.0
# 5    0.0
# 6    4.0
# 7    0.0
# 8    3.0
# 9    0.0
# Name: Happiness Value, dtype: float64

# %%
df3=df2.copy()

# %%
leb = LabelEncoder()
col= ['Connection Type', 'Device','Device Type', 'Browser', 'Browser Version', 'OS', 'OS Version','End Time',
      'End of Playback Status']
df3[col]= df3[col].apply(leb.fit_transform)
df3
# Out:
#                 Start Time  Playtime  Effective Playtime  Interruptions  \
# 0      2022-07-12 00:00:14  0.000127            0.000116       0.000000
# 1      2022-07-12 00:00:38  0.000845            0.000833       0.000000
# 2      2022-07-12 00:02:02  0.000243            0.000231       0.000000
# 3      2022-07-12 00:02:24  0.000012            0.000000       0.000000
# 4      2022-07-12 00:02:25  0.000012            0.000000       0.000000
# ...                    ...       ...                 ...            ...
# 102251 2022-07-25 23:06:05  0.176867            0.000000       0.000000
# 102252 2022-07-25 22:55:39  0.191912            0.191905       0.000000
# 102253 2022-07-25 23:09:33  0.244966            0.000000       0.000000
# 102254 2022-07-25 11:47:37  0.753692            0.753628       0.000528
# 102255 2022-07-25 14:07:08  0.877702            0.876334       0.000000
#
#         Join Time  Buffer Ratio  Connection Type  Device  Device Type  \
# 0        0.007325       0.00000                7       1           10
# 1        0.009750       0.00000               16       1           10
# 2        0.009442       0.00000               16       1           10
# 3        0.000000       0.00000               16       1           10
# 4        0.000000       0.00000               16       1           10
# ...           ...           ...              ...     ...          ...
# 102251   0.000000       0.00000                8      14            8
# 102252   0.008250       0.00000               16       1           10
# 102253   0.000000       0.00000               16       0            6
# 102254   0.050858       0.00001               12       8            3
# 102255   1.000000       0.00000               16       0            6
#
#         Browser  ...  Startup Error (Count)   Latency  End Time  \
# 0             0  ...                    0.0  0.054257         0
# 1             0  ...                    0.0  0.052946         1
# 2             0  ...                    0.0  0.053052         2
# 3             0  ...                    0.0  0.000000         3
# 4             0  ...                    0.0  0.000000         4
# ...         ...  ...                    ...       ...       ...
# 102251        7  ...                    0.0  0.000000     96246
# 102252        0  ...                    0.0  0.050604     96247
# 102253        0  ...                    0.0  0.000000     96248
# 102254        1  ...                    0.0  0.076639     96249
# 102255        0  ...                    1.0  0.100938     96250
#
#         End of Playback Status   Title_N  Device_Vendor_N  Device_Model_N  \
# 0                            3  0.478632         0.666667        0.392638
# 1                            3  0.000611         0.541667        0.386503
# 2                            3  0.479853         0.541667        0.386503
# 3                            3  0.608669         0.541667        0.386503
# 4                            3  0.608669         0.541667        0.386503
# ...                        ...       ...              ...             ...
# 102251                       3  0.918193         0.083333        0.938650
# 102252                       3  0.619048         0.541667        0.386503
# 102253                       3  0.656899         0.666667        0.251534
# 102254                       3  0.877289         0.333333        0.969325
# 102255                       3  0.550672         0.541667        0.092025
#
#         Country_N    City_N  Region_N
# 0        0.214286  0.649383       0.0
# 1        0.214286  0.187654       0.0
# 2        0.214286  0.187654       0.0
# 3        0.214286  0.187654       0.0
# 4        0.214286  0.187654       0.0
# ...           ...       ...       ...
# 102251   0.214286  0.906173       0.0
# 102252   0.214286  0.096296       0.0
# 102253   0.214286  0.138272       0.0
# 102254   0.214286  0.138272       0.0
# 102255   0.214286  0.649383       0.0
#
# [102255 rows x 25 columns]

# %% [markdown]
# ### preprocessing 'Start Time'

# %%
df3['Start Time'].head(5)
# Out:
# 0   2022-07-12 00:00:14
# 1   2022-07-12 00:00:38
# 2   2022-07-12 00:02:02
# 3   2022-07-12 00:02:24
# 4   2022-07-12 00:02:25
# Name: Start Time, dtype: datetime64[ns]

# %%
df3['Start Time'] = pd.to_datetime(df3['Start Time'])
df3 = df3.sort_values('Start Time')
df3.set_index('Start Time', inplace=True)

# %%
corr_matrix = df3.corr().abs()
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
to_drop = [column for column in upper.columns if any(upper[column] > 0.8)]
# Out:
# C:\Users\souha\AppData\Local\Temp\ipykernel_3616\2163488280.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# %%
to_drop
# Out:
# ['Effective Playtime',
#  'Browser Version',
#  'OS',
#  'OS Version',
#  'Happiness Score',
#  'End Time']

# %%
df3 = df.drop(df[to_drop], axis=1)

# %%
import pandas as pd
df3.to_pickle("my_preprocessed_data.pkl")
